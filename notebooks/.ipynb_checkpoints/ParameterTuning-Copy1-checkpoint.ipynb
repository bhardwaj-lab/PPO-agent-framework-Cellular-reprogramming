# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
print(os.getcwd())
os.chdir('../../complete_project/../')
print(os.getcwd())
# Then set up the paths
# import sys

# import os
# os.environ['PYTHONPATH'] = os.getcwd()  # Now points to thesis_code directory
# sys.path.append(os.environ['PYTHONPATH'])
sys.path.append("/home/caspar/thesis_code/CellOracle")
sys.path.append("/home/caspar/thesis_code/complete_project/py files")
sys.path.append("/home/caspar/thesis_code/complete_project/py files/AIFiles")
sys.path.append("/home/caspar/thesis_code/complete_project/py files/baseGRNConstructionFiles")
sys.path.append("/home/caspar/thesis_code/complete_project/py files/oracleInferenceFiles")
sys.path.append("/home/caspar/thesis_code/complete_project/py files/oracleSetup")
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import anndata
import sys
import logging
from datetime import datetime
import wandb
import optuna
#import modified_celloracle as mco
from CellOracle import celloracle as co

import CellOracleSetup as setup_module
import GRNClusterAnalysis as analysis_module
import GRNInference as inference_module
import GRNInferenceTest as inference_test_module

log_dir = 'logs'
os.makedirs(log_dir, exist_ok=True)
log_filename = os.path.join(log_dir, f"app_{datetime.now().strftime('%Y_%m_%d')}.log")

# Configure the basic logging
logging.basicConfig(
    filename=log_filename,
    filemode='a',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
# Out:
# /home/caspar/thesis_code/complete_project/notebooks
# /home/caspar/thesis_code

# %%
# !nvidia-smi
# Out:
# Fri Jun  6 13:09:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.06              Driver Version: 555.42.06      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX 6000 Ada Gene...    Off |   00000000:AC:00.0  On |                  Off |
# | 30%   38C    P8             25W /  300W |   14810MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX 6000 Ada Gene...    Off |   00000000:CA:00.0 Off |                  Off |
# | 71%   74C    P0            295W /  300W |   35934MiB /  49140MiB |    100%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     69090      C   ...da3/envs/gpu_cell_oracle/bin/python      14776MiB |
# |    1   N/A  N/A   3776787      C   python                                      35924MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os
import torch.nn as nn
import AI as ai_module # Import the refactored script
import ParameterTuning as tuning_module # Import the refactored script

data_path_new_data = os.path.join('../celloracle_data', "celloracle_object/new_promoter_without_mescs_trimmed_test_own_umap")
base_config = {
    # Paths
    "ORACLE_PATH": os.path.join(data_path_new_data, "ready_oracle.pkl"),
    "MODEL_SAVE_PATH_BASE": os.path.join("../celloracle_data", "optuna_hpo_models2"), # Base for HPO trial models
    "LOG_DIR_BASE": os.path.join('../celloracle_data', "optuna_hpo_logs2"),         # Base for HPO trial logs
    "WAND_B_LOG_DIR_BASE": os.path.join('../celloracle_data', "optuna_hpo_wandb_logs2"), # Base for HPO trial wandb logs
    "HPO_FIXED_MAX_STEPS_PER_EPISODE": 20, 
    "TRANSITION_MATRIX": os.path.join("../celloracle_data/transition_matrix", "transition_matrix.pkl"), # Path to transition matrix


    "BATCH_SIZE": 256,
    "USE_MASKABLE_PPO": False, 
    "VERBOSE": 0,              
    "LOG_INTERVAL": 10,
    "RESET_NUM_TIMESTEPS": False,
    "DEVICE": "auto",
    "USE_PROGRESS_BAR": False,  
    "STEP_SAVE_FREQ": 1000000000, 
    "PPO_N_STEPS": 512,
    "PPO_N_EPOCHS": 10,
    "GAMMA": 0.99,
    "GAE_LAMBDA": 0.95,
    "CLIP_RANGE": 0.2,
    "ENT_COEF": 0.01,       
    "VF_COEF": 0.5,
    "MAX_GRAD_NORM": 0.5,
    "LEARNING_RATE": 3e-4,  

    # Environment Specific 
    "ALLOW_GENE_ACTIVATION": True,
    "STANDARD_SD_FACTOR": 1.5,
    "USE_LEARNING_RATE_SCHEDULE": False, 
    "USE_SIMILARITY_REWARD": True,
    "ENV_TYPE": "FAST",  #options: FIRST,NEW_INPUT, GENERAL,FAST
    "USE_PREV_KNOCKOUT": True, 

    # ENV HYPERPARAMETERS (Some will be tuned by Optuna)
    "DIVIDER_OF_TOTAL_STEPS_FOR_CURRICULUM_LEARNING": 20,
    "TARGET_CELLS_PER_PHASE": 14,
    "MAX_STEP_INCREASE_PER_PHASE": 8,
    "MAX_STEPS_FIRST_PHASE": 50000, 
    "PHASE_STEP_INCREASE": 15000,
    "MAX_STEPS_PER_EPISODE": 42,
    "OPTUNA_REPORT_INTERVAL": 10000,

    # Other ENV params
    "GENE_ACTIVITY_THRESHOLD": 0.01,
    "TARGET_DISTANCE_THRESHOLD": 0.1,
    "DISTANCE_GAMMA": 0.99,           
    "STEP_PENALTY": -0.05,
    "GOAL_BONUS": 10,
    "FAIL_PENALTY": -3,
    "SAME_CELL_PENALTY": -0.5,
    "DISTANCE_REWARD_SCALE": 5,
    "PARAMETER_TUNING":True,
    "TOTAL_TIMESTEPS_HPO": 300000,
    "STUDY_NAME": "ppo_celloracle_hpo_general20",
    "STORAGE_NAME": "sqlite:///ppo_celloracle_hpo_general20.db",

    # NN Architecture (Fixed for this example, but can be tuned)
    "PI_ARCH": [512,256],
    "VF_ARCH": [512,256],
    "ACTIVATION_FN": nn.ReLU, # Make sure nn is imported if you use this directly
    
}

if base_config["USE_SIMILARITY_REWARD"]:
    base_config["DISTANCE_REWARD_SCALE"] = 50
else:
    base_config["DISTANCE_REWARD_SCALE"] = 5

trained_model = tuning_module.run_optuna_hpo(base_config)
# Out:
# [I 2025-09-09 13:21:53,418] Using an existing study with name 'ppo_celloracle_hpo_general20' instead of creating a new one.
# running number of trials: 4
#
# --- Starting Optuna HPO Study: ppo_celloracle_hpo_general20 ---
# test
#
# ---> Starting Optuna Trial 3 <---
#   --- Hyperparameters for this Trial ---
#   PPO Agent:
#     Learning Rate: 0.000071
#     N_Steps: 256
#     N_Epochs: 7
#     Clip Range: 0.1468
#     Entropy Coef: 0.001162
#     Gamma (Discount): 0.9946
#   Reward Function:
#     Goal Bonus: 1.1853
#     Fail Penalty: -3.6273
#     Step Penalty: -0.0918
#     Same Cell Penalty: -0.5903
#     Distance Reward Scale: 67.9896
#     Distance Gamma (PBRS): 0.9685
#   ------------------------------------
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: caspar-christiaan (caspar-christiaan-utrecht-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>../celloracle_data/optuna_hpo_wandb_logs2/wandb/run-20250909_132157-zrt4ehos</code>
# Syncing run <strong><a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/zrt4ehos' target="_blank">2025-09-09_13-21-55_1.185260448662222_-3.627346799835591_-0.09179929788622242_67.9896242159113_True</a></strong> to <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt</a>
#  View run at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/zrt4ehos' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/zrt4ehos</a>
# --- Starting Training Run ---
# Configuration: {'ORACLE_PATH': '../celloracle_data/celloracle_object/new_promoter_without_mescs_trimmed_test_own_umap/ready_oracle.pkl', 'MODEL_SAVE_PATH_BASE': '../celloracle_data/optuna_hpo_models2', 'LOG_DIR_BASE': '../celloracle_data/optuna_hpo_logs2', 'WAND_B_LOG_DIR_BASE': '../celloracle_data/optuna_hpo_wandb_logs2', 'HPO_FIXED_MAX_STEPS_PER_EPISODE': 20, 'TRANSITION_MATRIX': '../celloracle_data/transition_matrix/transition_matrix.pkl', 'BATCH_SIZE': 256, 'USE_MASKABLE_PPO': False, 'VERBOSE': 0, 'LOG_INTERVAL': 10, 'RESET_NUM_TIMESTEPS': False, 'DEVICE': 'auto', 'USE_PROGRESS_BAR': False, 'STEP_SAVE_FREQ': 1000000000, 'PPO_N_STEPS': 256, 'PPO_N_EPOCHS': 7, 'GAMMA': 0.9946470458309974, 'GAE_LAMBDA': 0.95, 'CLIP_RANGE': 0.1467983561008608, 'ENT_COEF': 0.0011616722433639892, 'VF_COEF': 0.5, 'MAX_GRAD_NORM': 0.5, 'LEARNING_RATE': 7.106591851092232e-05, 'ALLOW_GENE_ACTIVATION': True, 'STANDARD_SD_FACTOR': 1.5, 'USE_LEARNING_RATE_SCHEDULE': False, 'USE_SIMILARITY_REWARD': True, 'ENV_TYPE': 'FAST', 'USE_PREV_KNOCKOUT': True, 'DIVIDER_OF_TOTAL_STEPS_FOR_CURRICULUM_LEARNING': 20, 'TARGET_CELLS_PER_PHASE': 14, 'MAX_STEP_INCREASE_PER_PHASE': 8, 'MAX_STEPS_FIRST_PHASE': 50000, 'PHASE_STEP_INCREASE': 15000, 'MAX_STEPS_PER_EPISODE': 42, 'OPTUNA_REPORT_INTERVAL': 10000, 'GENE_ACTIVITY_THRESHOLD': 0.01, 'TARGET_DISTANCE_THRESHOLD': 0.1, 'DISTANCE_GAMMA': 0.968493564427131, 'STEP_PENALTY': -0.09179929788622242, 'GOAL_BONUS': 1.185260448662222, 'FAIL_PENALTY': -3.627346799835591, 'SAME_CELL_PENALTY': -0.5902704435140169, 'DISTANCE_REWARD_SCALE': 67.9896242159113, 'PARAMETER_TUNING': True, 'TOTAL_TIMESTEPS_HPO': 300000, 'STUDY_NAME': 'ppo_celloracle_hpo_general20', 'STORAGE_NAME': 'sqlite:///ppo_celloracle_hpo_general20.db', 'PI_ARCH': [512, 256], 'VF_ARCH': [512, 256], 'ACTIVATION_FN': <class 'torch.nn.modules.activation.ReLU'>, 'MODEL_SAVE_PATH': '../celloracle_data/optuna_hpo_models2/trial_3', 'LOG_DIR': '../celloracle_data/optuna_hpo_logs2/trial_3', 'WANDB_RUN_NAME': 't3_lr7.1e-05_ent0.00', 'optuna_trial_obj': <optuna.trial._trial.Trial object at 0x74b3c1aa0d00>, 'TOTAL_TIMESTEPS': 300000}
# Initializing CellOracleCustomEnv with batch_size=256...
# CuPy is available and GPU is accessible.
# loaded
# Raw data min: 0.0, max: 18.71354292543993
# AnnData object with n_obs × n_vars = 30000 × 3000
#     obs: 'bc_idx', 'colnames', 'obs_names', 'celltype', 'celltype_general'
#     var: 'rownames', 'mean', 'std', 'symbol', 'isin_top1000_var_mean_genes', 'isin_TFdict_targets', 'isin_TFdict_regulators', 'isin_actve_regulators'
#     uns: 'celltype_colors', 'neighbors', 'pca', 'umap', 'umap_neighbors_sparse'
#     obsm: 'X_pca', 'X_umap', 'colnames_factor', 'umap_neighbors'
#     varm: 'PCs'
#     layers: 'chic', 'raw_chich_counts', 'raw_count', 'unspliced_spliced', 'normalized_count', 'imputed_count', 'simulation_input'
#     obsp: 'connectivities', 'distances', 'umap_neighbors_sparse'
# Finished calculating activation values for 108 genes.
# get attribute called with name:  render_mode
# get attribute called with indices:  None
# UMAP coordinates normalized with StandardScaler with amx:  0.99999994  and min:  -1.0
# Calculating centroid for celltype: Floor Plate Neural Tube, number of cells: 3024
# Final centroid for celltype Floor Plate Neural Tube: [0.15103018 3.5827925 ], norm: [-0.26755098 -0.36702746]
# Calculating centroid for celltype: Reprogramming PGCs, number of cells: 410
# Final centroid for celltype Reprogramming PGCs: [-0.13800415 10.545729  ], norm: [-0.30736113  0.52565503]
# Calculating centroid for celltype: Caudal Mesoderm, number of cells: 2869
# Final centroid for celltype Caudal Mesoderm: [-0.34028184  8.111842  ], norm: [-0.33522215  0.21362104]
# Calculating centroid for celltype: Naive PGCs, number of cells: 1580
# Final centroid for celltype Naive PGCs: [-0.36913848 12.424707  ], norm: [-0.33919668  0.76654875]
# Calculating centroid for celltype: Epiblast, number of cells: 1999
# Final centroid for celltype Epiblast: [-3.0602849 11.13454  ], norm: [-0.70986354  0.60114324]
# Calculating centroid for celltype: NMPs, number of cells: 1076
# Final centroid for celltype NMPs: [0.3204247 6.6997905], norm: [-0.24421889  0.03258687]
# Calculating centroid for celltype: (pre)Somitic/Wavefront, number of cells: 1143
# Final centroid for celltype (pre)Somitic/Wavefront: [1.4744222 7.961644 ], norm: [-0.08527257  0.19436264]
# Calculating centroid for celltype: Dermomyotome, number of cells: 1208
# Final centroid for celltype Dermomyotome: [3.346641 5.715721], norm: [ 0.17259867 -0.09357524]
# Calculating centroid for celltype: PGCs, number of cells: 1080
# Final centroid for celltype PGCs: [ 0.35939455 12.803531  ], norm: [-0.23885158  0.8151156 ]
# Calculating centroid for celltype: LP/Intermediate Mesoderm, number of cells: 1079
# Final centroid for celltype LP/Intermediate Mesoderm: [4.1093826 6.2413793], norm: [ 0.27765545 -0.0261833 ]
# Calculating centroid for celltype: Pharyngeal Mesoderm, number of cells: 967
# Final centroid for celltype Pharyngeal Mesoderm: [5.4362154 6.075975 ], norm: [ 0.46040708 -0.04738893]
# Calculating centroid for celltype: Caudal Epiblast, number of cells: 2634
# Final centroid for celltype Caudal Epiblast: [-0.7592888  9.8951235], norm: [-0.39293417  0.4422448 ]
# Calculating centroid for celltype: Neural Progenitors, number of cells: 1861
# Final centroid for celltype Neural Progenitors: [-0.19399272  5.780165  ], norm: [-0.3150727  -0.08531348]
# Calculating centroid for celltype: Late Motor Neurons, number of cells: 840
# Final centroid for celltype Late Motor Neurons: [3.319404  0.4959957], norm: [ 0.16884682 -0.7627698 ]
# Calculating centroid for celltype: Cardiac Mesoderm, number of cells: 720
# Final centroid for celltype Cardiac Mesoderm: [5.5995193 8.459149 ], norm: [0.4829008  0.25814468]
# Calculating centroid for celltype: Early Motor Neurons, number of cells: 793
# Final centroid for celltype Early Motor Neurons: [2.182444  2.2965121], norm: [ 0.01224715 -0.5319347 ]
# Calculating centroid for celltype: Roof Plate Neural Tube, number of cells: 1336
# Final centroid for celltype Roof Plate Neural Tube: [-1.1425856  4.133491 ], norm: [-0.44572777 -0.29642552]
# Calculating centroid for celltype: Primitive Streak, number of cells: 183
# Final centroid for celltype Primitive Streak: [ 0.41268933 10.246578  ], norm: [-0.23151112  0.48730245]
# Calculating centroid for celltype: Nascent Mesoderm, number of cells: 730
# Final centroid for celltype Nascent Mesoderm: [3.5888844 9.237035 ], norm: [0.20596404 0.3578744 ]
# Calculating centroid for celltype: Visceral Endoderm, number of cells: 1931
# Final centroid for celltype Visceral Endoderm: [ 4.248622 11.432925], norm: [0.29683396 0.6393976 ]
# Calculating centroid for celltype: Endothelium, number of cells: 436
# Final centroid for celltype Endothelium: [8.347851  6.3133297], norm: [ 0.86144304 -0.01695901]
# Calculating centroid for celltype: ExE Endoderm, number of cells: 582
# Final centroid for celltype ExE Endoderm: [ 5.838832 12.053093], norm: [0.51586205 0.7189068 ]
# Calculating centroid for celltype: Sclerotome, number of cells: 529
# Final centroid for celltype Sclerotome: [4.6159496 6.0439634], norm: [ 0.34742755 -0.05149309]
# Calculating centroid for celltype: (early) Somite, number of cells: 524
# Final centroid for celltype (early) Somite: [4.6244535 7.075751 ], norm: [0.34859833 0.08078694]
# Calculating centroid for celltype: Erythrocytes, number of cells: 68
# Final centroid for celltype Erythrocytes: [7.9770355 7.998386 ], norm: [0.81036866 0.19907323]
# Calculating centroid for celltype: Parietal Endoderm, number of cells: 128
# Final centroid for celltype Parietal Endoderm: [ 3.3503137 13.78757  ], norm: [0.1731044 0.9412746]
# Calculating centroid for celltype: Epidermis Progenitors, number of cells: 144
# Final centroid for celltype Epidermis Progenitors: [-4.64016  10.502207], norm: [-0.9274685   0.52007526]
# Calculating centroid for celltype: Megakaryocytes, number of cells: 53
# Final centroid for celltype Megakaryocytes: [8.893026 8.032934], norm: [0.9365332  0.20350246]
# Calculating centroid for celltype: Cardiomyocytes, number of cells: 53
# Final centroid for celltype Cardiomyocytes: [7.0683675 8.852559 ], norm: [0.68521273 0.30858237]
# Calculating centroid for celltype: Myotome, number of cells: 20
# Final centroid for celltype Myotome: [4.0142164 3.6796944], norm: [ 0.26454744 -0.35460392]
# Number of phases for curriculum learning: 4
# number of targets: 14
# 3 targets for phase 1
# 3 targets for phase 2
# 3 targets for phase 3
# 3 targets for phase 4
# Total curriculum targets computed for phases: 4
# Total curriculum targets for each phase: [3, 3, 3, 3]
# Total number of celltypes in curriculum: [14, 14, 14]
# Number of celltypes:  30  so without pcgs we have  27  targets
# Generating UMAP plot with goal regions (radius: 0.2)...
# Plot saved to: umap_with_goal_regions.png
# Policy architecture: {'net_arch': {'pi': [512, 256], 'vf': [512, 256]}, 'activation_fn': <class 'torch.nn.modules.activation.ReLU'>}
# Agent (PPO) instantiated with architecture: {'pi': [512, 256], 'vf': [512, 256]}
# Starting training for 300000 timesteps...
# Closing environment.
# Total goals achieved in this trial: 185
# Optuna Trial 3 completed. Final Metric (Mean Reward): 185.0000
# Finishing W&B run for trial 3 (Status: completed)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>██████████████▁▁▁▁▁▁▁▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>PPO_update/clip_fraction</td><td>▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▄▄▄▄▄▄▄▄▄▄▄▄▄████████████</td></tr><tr><td>PPO_update/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▅▅████████</td></tr><tr><td>PPO_update/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▇▇▇▇▇▇▇▇███████████████</td></tr><tr><td>PPO_update/value_loss</td><td>▆▆▆▆▆▆▆▆▆▆▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂██████</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>▂▅▁▃▄▇▄▃▅▆▅▂▂▆▃▆▂▅▃▇▆▂▄▄▆▇▂▄▄▇▅▄▇▃▅▆█▄▇▄</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>█████▁███▁████▁███▁▁██████████████▁█████</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>▂▅▆▇▅▅▆▂▄▅▄▆▅█▆▃▃▅▄▃▄▅▃▄▄▂▅▄▃▃▂▃▃▂▄▃▃▂▁▂</td></tr><tr><td>episode_overall/success_rate</td><td>██▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>episode_period/ep_len_mean</td><td>▁▆██▇█▇███▇▇█▇██████▇███▇█▇▇▇▇████▇██▇██</td></tr><tr><td>episode_period/success_rate</td><td>██▁▅▁▃▁▁▁▃▁▃▂▃▃▂▂▁▁▁▂▁▁▁▁▃▂▂▁▁▁▂▁▂▁▁▁▁▁▁</td></tr><tr><td>step_avg/average_distance</td><td>▄▃▅▄▂▃▄▄▁▃▆▅▄▄▂▂▆▄▄▄█▇▂▄▆▁▃▆▁▅▆▆▃▄▆▂▂▄▅▅</td></tr><tr><td>step_avg/average_goal</td><td>▁▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▅▁▁▅▁▅▁▅▁</td></tr><tr><td>step_avg/average_penalty</td><td>██████▁██████████████▃██████████████████</td></tr><tr><td>step_avg/average_same_cell</td><td>▅▅▅▄▆█▅▆▅▄▂▄▇▇▄▇▇▁▅▄▇▄▆▇▃▆▆▄▅▇▄▄▇▄▅▄▆▇▆▄</td></tr><tr><td>step_avg/percentage_of_activation</td><td>▃▂▅▄▆▃▄▆▃▄▄▂▄▆▅▃█▂▅▃▄▅▆▃▄▂▅▁▃▆▆▄▂▄▃▃▅▄▇▂</td></tr><tr><td>train/approx_kl</td><td>██████████▁▁▁▁▁▁▁▁▁▄▄▄▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>train/clip_fraction</td><td>▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▄▄▄▄▄▄▄▄▄████████</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅██████████</td></tr><tr><td>train/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▇▇▇▇▇▇▇▇▇▇██████</td></tr><tr><td>train/value_loss</td><td>▆▆▆▆▆▆▆▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂██████████</td></tr><tr><td>training_info/current_curriculum_phase</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/current_max_episode_steps</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/mean_reward</td><td>▆▅▅▄▆▃▆▄▆▁▄▆▇█▃▆▆▅▂▅▄█▇▅▄▃▃▄▄▄▃▆▆▇▆▅▄▃▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>0.00571</td></tr><tr><td>PPO_update/clip_fraction</td><td>0.0891</td></tr><tr><td>PPO_update/entropy_loss</td><td>-5.33777</td></tr><tr><td>PPO_update/explained_variance</td><td>0.44779</td></tr><tr><td>PPO_update/value_loss</td><td>54.60973</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>19</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>16</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>76</td></tr><tr><td>episode_overall/success_rate</td><td>0.02387</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>7751</td></tr><tr><td>episode_period/ep_len_mean</td><td>38.5</td></tr><tr><td>episode_period/success_rate</td><td>0.14286</td></tr><tr><td>final_metric_for_optuna</td><td>185</td></tr><tr><td>step_avg/average_distance</td><td>-1.34871</td></tr><tr><td>step_avg/average_goal</td><td>0</td></tr><tr><td>step_avg/average_pe ...
#  View run <strong style="color:#cdcd00">2025-09-09_13-21-55_1.185260448662222_-3.627346799835591_-0.09179929788622242_67.9896242159113_True</strong> at: <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/zrt4ehos' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/zrt4ehos</a><br> View project at: <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../celloracle_data/optuna_hpo_wandb_logs2/wandb/run-20250909_132157-zrt4ehos/logs</code>
# [I 2025-09-09 13:23:59,697] Trial 3 finished with value: 185.0 and parameters: {'LEARNING_RATE': 7.106591851092232e-05, 'PPO_N_STEPS': 256, 'PPO_N_EPOCHS': 7, 'CLIP_RANGE': 0.1467983561008608, 'ENT_COEF': 0.0011616722433639892, 'GAMMA': 0.9946470458309974, 'STEP_PENALTY': -0.09179929788622242, 'FAIL_PENALTY': -3.627346799835591, 'GOAL_BONUS': 1.185260448662222, 'SAME_CELL_PENALTY': -0.5902704435140169, 'DISTANCE_REWARD_SCALE': 67.9896242159113, 'DISTANCE_GAMMA': 0.968493564427131}. Best is trial 1 with value: 259.0.
# ---> Starting Optuna Trial 6 <---
#   --- Hyperparameters for this Trial ---
#   PPO Agent:
#     Learning Rate: 0.000046
#     N_Steps: 1024
#     N_Epochs: 11
#     Clip Range: 0.1874
#     Entropy Coef: 0.012237
#     Gamma (Discount): 0.9656
#   Reward Function:
#     Goal Bonus: 5.1046
#     Fail Penalty: -6.7027
#     Step Penalty: -0.1474
#     Same Cell Penalty: -1.1445
#     Distance Reward Scale: 15.8370
#     Distance Gamma (PBRS): 0.9806
#   ------------------------------------
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>../celloracle_data/optuna_hpo_wandb_logs2/wandb/run-20250909_132401-2gnt9vxv</code>
# Syncing run <strong><a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/2gnt9vxv' target="_blank">2025-09-09_13-24-01_5.104629857953324_-6.702743410356774_-0.14741396326366074_15.83703155911875_True</a></strong> to <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt</a>
#  View run at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/2gnt9vxv' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/2gnt9vxv</a>
# --- Starting Training Run ---
# Configuration: {'ORACLE_PATH': '../celloracle_data/celloracle_object/new_promoter_without_mescs_trimmed_test_own_umap/ready_oracle.pkl', 'MODEL_SAVE_PATH_BASE': '../celloracle_data/optuna_hpo_models2', 'LOG_DIR_BASE': '../celloracle_data/optuna_hpo_logs2', 'WAND_B_LOG_DIR_BASE': '../celloracle_data/optuna_hpo_wandb_logs2', 'HPO_FIXED_MAX_STEPS_PER_EPISODE': 20, 'TRANSITION_MATRIX': '../celloracle_data/transition_matrix/transition_matrix.pkl', 'BATCH_SIZE': 256, 'USE_MASKABLE_PPO': False, 'VERBOSE': 0, 'LOG_INTERVAL': 10, 'RESET_NUM_TIMESTEPS': False, 'DEVICE': 'auto', 'USE_PROGRESS_BAR': False, 'STEP_SAVE_FREQ': 1000000000, 'PPO_N_STEPS': 1024, 'PPO_N_EPOCHS': 11, 'GAMMA': 0.9655797544260817, 'GAE_LAMBDA': 0.95, 'CLIP_RANGE': 0.1873687420594126, 'ENT_COEF': 0.01223705789444759, 'VF_COEF': 0.5, 'MAX_GRAD_NORM': 0.5, 'LEARNING_RATE': 4.5598044903929383e-05, 'ALLOW_GENE_ACTIVATION': True, 'STANDARD_SD_FACTOR': 1.5, 'USE_LEARNING_RATE_SCHEDULE': False, 'USE_SIMILARITY_REWARD': True, 'ENV_TYPE': 'FAST', 'USE_PREV_KNOCKOUT': True, 'DIVIDER_OF_TOTAL_STEPS_FOR_CURRICULUM_LEARNING': 20, 'TARGET_CELLS_PER_PHASE': 14, 'MAX_STEP_INCREASE_PER_PHASE': 8, 'MAX_STEPS_FIRST_PHASE': 50000, 'PHASE_STEP_INCREASE': 15000, 'MAX_STEPS_PER_EPISODE': 42, 'OPTUNA_REPORT_INTERVAL': 10000, 'GENE_ACTIVITY_THRESHOLD': 0.01, 'TARGET_DISTANCE_THRESHOLD': 0.1, 'DISTANCE_GAMMA': 0.9805693775365445, 'STEP_PENALTY': -0.14741396326366074, 'GOAL_BONUS': 5.104629857953324, 'FAIL_PENALTY': -6.702743410356774, 'SAME_CELL_PENALTY': -1.1444721158209594, 'DISTANCE_REWARD_SCALE': 15.83703155911875, 'PARAMETER_TUNING': True, 'TOTAL_TIMESTEPS_HPO': 300000, 'STUDY_NAME': 'ppo_celloracle_hpo_general20', 'STORAGE_NAME': 'sqlite:///ppo_celloracle_hpo_general20.db', 'PI_ARCH': [512, 256], 'VF_ARCH': [512, 256], 'ACTIVATION_FN': <class 'torch.nn.modules.activation.ReLU'>, 'MODEL_SAVE_PATH': '../celloracle_data/optuna_hpo_models2/trial_6', 'LOG_DIR': '../celloracle_data/optuna_hpo_logs2/trial_6', 'WANDB_RUN_NAME': 't6_lr4.6e-05_ent0.01', 'optuna_trial_obj': <optuna.trial._trial.Trial object at 0x74b3c18ca5c0>, 'TOTAL_TIMESTEPS': 300000}
# Initializing CellOracleCustomEnv with batch_size=256...
# CuPy is available and GPU is accessible.
# loaded
# Raw data min: 0.0, max: 18.71354292543993
# AnnData object with n_obs × n_vars = 30000 × 3000
#     obs: 'bc_idx', 'colnames', 'obs_names', 'celltype', 'celltype_general'
#     var: 'rownames', 'mean', 'std', 'symbol', 'isin_top1000_var_mean_genes', 'isin_TFdict_targets', 'isin_TFdict_regulators', 'isin_actve_regulators'
#     uns: 'celltype_colors', 'neighbors', 'pca', 'umap', 'umap_neighbors_sparse'
#     obsm: 'X_pca', 'X_umap', 'colnames_factor', 'umap_neighbors'
#     varm: 'PCs'
#     layers: 'chic', 'raw_chich_counts', 'raw_count', 'unspliced_spliced', 'normalized_count', 'imputed_count', 'simulation_input'
#     obsp: 'connectivities', 'distances', 'umap_neighbors_sparse'
# Finished calculating activation values for 108 genes.
# get attribute called with name:  render_mode
# get attribute called with indices:  None
# UMAP coordinates normalized with StandardScaler with amx:  0.99999994  and min:  -1.0
# Calculating centroid for celltype: Floor Plate Neural Tube, number of cells: 3024
# Final centroid for celltype Floor Plate Neural Tube: [0.15103018 3.5827925 ], norm: [-0.26755098 -0.36702746]
# Calculating centroid for celltype: Reprogramming PGCs, number of cells: 410
# Final centroid for celltype Reprogramming PGCs: [-0.13800415 10.545729  ], norm: [-0.30736113  0.52565503]
# Calculating centroid for celltype: Caudal Mesoderm, number of cells: 2869
# Final centroid for celltype Caudal Mesoderm: [-0.34028184  8.111842  ], norm: [-0.33522215  0.21362104]
# Calculating centroid for celltype: Naive PGCs, number of cells: 1580
# Final centroid for celltype Naive PGCs: [-0.36913848 12.424707  ], norm: [-0.33919668  0.76654875]
# Calculating centroid for celltype: Epiblast, number of cells: 1999
# Final centroid for celltype Epiblast: [-3.0602849 11.13454  ], norm: [-0.70986354  0.60114324]
# Calculating centroid for celltype: NMPs, number of cells: 1076
# Final centroid for celltype NMPs: [0.3204247 6.6997905], norm: [-0.24421889  0.03258687]
# Calculating centroid for celltype: (pre)Somitic/Wavefront, number of cells: 1143
# Final centroid for celltype (pre)Somitic/Wavefront: [1.4744222 7.961644 ], norm: [-0.08527257  0.19436264]
# Calculating centroid for celltype: Dermomyotome, number of cells: 1208
# Final centroid for celltype Dermomyotome: [3.346641 5.715721], norm: [ 0.17259867 -0.09357524]
# Calculating centroid for celltype: PGCs, number of cells: 1080
# Final centroid for celltype PGCs: [ 0.35939455 12.803531  ], norm: [-0.23885158  0.8151156 ]
# Calculating centroid for celltype: LP/Intermediate Mesoderm, number of cells: 1079
# Final centroid for celltype LP/Intermediate Mesoderm: [4.1093826 6.2413793], norm: [ 0.27765545 -0.0261833 ]
# Calculating centroid for celltype: Pharyngeal Mesoderm, number of cells: 967
# Final centroid for celltype Pharyngeal Mesoderm: [5.4362154 6.075975 ], norm: [ 0.46040708 -0.04738893]
# Calculating centroid for celltype: Caudal Epiblast, number of cells: 2634
# Final centroid for celltype Caudal Epiblast: [-0.7592888  9.8951235], norm: [-0.39293417  0.4422448 ]
# Calculating centroid for celltype: Neural Progenitors, number of cells: 1861
# Final centroid for celltype Neural Progenitors: [-0.19399272  5.780165  ], norm: [-0.3150727  -0.08531348]
# Calculating centroid for celltype: Late Motor Neurons, number of cells: 840
# Final centroid for celltype Late Motor Neurons: [3.319404  0.4959957], norm: [ 0.16884682 -0.7627698 ]
# Calculating centroid for celltype: Cardiac Mesoderm, number of cells: 720
# Final centroid for celltype Cardiac Mesoderm: [5.5995193 8.459149 ], norm: [0.4829008  0.25814468]
# Calculating centroid for celltype: Early Motor Neurons, number of cells: 793
# Final centroid for celltype Early Motor Neurons: [2.182444  2.2965121], norm: [ 0.01224715 -0.5319347 ]
# Calculating centroid for celltype: Roof Plate Neural Tube, number of cells: 1336
# Final centroid for celltype Roof Plate Neural Tube: [-1.1425856  4.133491 ], norm: [-0.44572777 -0.29642552]
# Calculating centroid for celltype: Primitive Streak, number of cells: 183
# Final centroid for celltype Primitive Streak: [ 0.41268933 10.246578  ], norm: [-0.23151112  0.48730245]
# Calculating centroid for celltype: Nascent Mesoderm, number of cells: 730
# Final centroid for celltype Nascent Mesoderm: [3.5888844 9.237035 ], norm: [0.20596404 0.3578744 ]
# Calculating centroid for celltype: Visceral Endoderm, number of cells: 1931
# Final centroid for celltype Visceral Endoderm: [ 4.248622 11.432925], norm: [0.29683396 0.6393976 ]
# Calculating centroid for celltype: Endothelium, number of cells: 436
# Final centroid for celltype Endothelium: [8.347851  6.3133297], norm: [ 0.86144304 -0.01695901]
# Calculating centroid for celltype: ExE Endoderm, number of cells: 582
# Final centroid for celltype ExE Endoderm: [ 5.838832 12.053093], norm: [0.51586205 0.7189068 ]
# Calculating centroid for celltype: Sclerotome, number of cells: 529
# Final centroid for celltype Sclerotome: [4.6159496 6.0439634], norm: [ 0.34742755 -0.05149309]
# Calculating centroid for celltype: (early) Somite, number of cells: 524
# Final centroid for celltype (early) Somite: [4.6244535 7.075751 ], norm: [0.34859833 0.08078694]
# Calculating centroid for celltype: Erythrocytes, number of cells: 68
# Final centroid for celltype Erythrocytes: [7.9770355 7.998386 ], norm: [0.81036866 0.19907323]
# Calculating centroid for celltype: Parietal Endoderm, number of cells: 128
# Final centroid for celltype Parietal Endoderm: [ 3.3503137 13.78757  ], norm: [0.1731044 0.9412746]
# Calculating centroid for celltype: Epidermis Progenitors, number of cells: 144
# Final centroid for celltype Epidermis Progenitors: [-4.64016  10.502207], norm: [-0.9274685   0.52007526]
# Calculating centroid for celltype: Megakaryocytes, number of cells: 53
# Final centroid for celltype Megakaryocytes: [8.893026 8.032934], norm: [0.9365332  0.20350246]
# Calculating centroid for celltype: Cardiomyocytes, number of cells: 53
# Final centroid for celltype Cardiomyocytes: [7.0683675 8.852559 ], norm: [0.68521273 0.30858237]
# Calculating centroid for celltype: Myotome, number of cells: 20
# Final centroid for celltype Myotome: [4.0142164 3.6796944], norm: [ 0.26454744 -0.35460392]
# Number of phases for curriculum learning: 4
# number of targets: 14
# 3 targets for phase 1
# 3 targets for phase 2
# 3 targets for phase 3
# 3 targets for phase 4
# Total curriculum targets computed for phases: 4
# Total curriculum targets for each phase: [3, 3, 3, 3]
# Total number of celltypes in curriculum: [14, 14, 14]
# Number of celltypes:  30  so without pcgs we have  27  targets
# Generating UMAP plot with goal regions (radius: 0.2)...
# Plot saved to: umap_with_goal_regions.png
# Policy architecture: {'net_arch': {'pi': [512, 256], 'vf': [512, 256]}, 'activation_fn': <class 'torch.nn.modules.activation.ReLU'>}
# Agent (PPO) instantiated with architecture: {'pi': [512, 256], 'vf': [512, 256]}
# Starting training for 300000 timesteps...
# Closing environment.
# Total goals achieved in this trial: 245
# Optuna Trial 6 completed. Final Metric (Mean Reward): 245.0000
# Finishing W&B run for trial 6 (Status: completed)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>▂▂▅▂▄▅▂▂▅▅▁▅▅▇█▂▃▂▁▂▁▅▂▃▅▅▅▅▄▅▄▆▃▂▂▂▄▅▇▂</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>██▁▁█▅██▅███████████████████████████████</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>▇▆▅▂█▇▅█▅█▆▄▅▇▆▄▃▅▆▅▇▄▃▅▄▃▆▂▂▄▅▁▆▃▂▆▅▁▃▃</td></tr><tr><td>episode_overall/success_rate</td><td>▂▁▂▄▅▅▅▅▅▆▅▆▆▆▆▆▆▆▆▇▆▇▇▇▇███████████████</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>episode_period/ep_len_mean</td><td>█▄██▁█████▇▇█▇██████▇██████▇████████████</td></tr><tr><td>episode_period/success_rate</td><td>▁█▃▃▅▁▃▂▂▂▂▁▂▁▁▂▁▂▁▂▂▁▁▁▂▂▁▁▁▁▂▁▁▁▁▁▁▁▂▁</td></tr><tr><td>step_avg/average_distance</td><td>▃▃▅▃█▂▅▄▃▅▃▂▅▄▅▃▄▃▃▅▄▄▆▁▃▇▂▃▂▃▆▄▄▃▆▂▃▃▃▄</td></tr><tr><td>step_avg/average_goal</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁█▁█▁▁▁▁▁▁▁█▁▁▁█▁▁▁▁▁▁</td></tr><tr><td>step_avg/average_penalty</td><td>█████████▁██████████████████▃████▄██████</td></tr><tr><td>step_avg/average_same_cell</td><td>▅▄▄▅▄█▂▂▇▂▅▂▃▄▄▁▄▆▆▆▄▆█▄▆▆▂█▂▄▇▆█▆▄█▅█▃▅</td></tr><tr><td>step_avg/percentage_of_activation</td><td>▁▂▁▁▁▄▂▄▁▂█▂▄▂▃▂▄▂▅▂▄▂▄▂▅▅▂▃▃▄▄▁▃▃▃▂▁▄▄▃</td></tr><tr><td>train/approx_kl</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/current_curriculum_phase</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/current_max_episode_steps</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/mean_reward</td><td>█████████▁█████▂████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>0.01076</td></tr><tr><td>PPO_update/clip_fraction</td><td>0.14498</td></tr><tr><td>PPO_update/entropy_loss</td><td>-5.36489</td></tr><tr><td>PPO_update/explained_variance</td><td>-0.01005</td></tr><tr><td>PPO_update/value_loss</td><td>1.85576</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>18</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>16</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>106</td></tr><tr><td>episode_overall/success_rate</td><td>0.01952</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>12398</td></tr><tr><td>episode_period/ep_len_mean</td><td>42</td></tr><tr><td>episode_period/success_rate</td><td>0</td></tr><tr><td>final_metric_for_optuna</td><td>245</td></tr><tr><td>step_avg/average_distance</td><td>-0.17139</td></tr><tr><td>step_avg/average_goal</td><td>0</td></tr><tr><td>step_avg/average_penalty ...
#  View run <strong style="color:#cdcd00">2025-09-09_13-24-01_5.104629857953324_-6.702743410356774_-0.14741396326366074_15.83703155911875_True</strong> at: <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/2gnt9vxv' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/2gnt9vxv</a><br> View project at: <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../celloracle_data/optuna_hpo_wandb_logs2/wandb/run-20250909_132401-2gnt9vxv/logs</code>
# [I 2025-09-09 13:27:40,899] Trial 6 finished with value: 245.0 and parameters: {'LEARNING_RATE': 4.5598044903929383e-05, 'PPO_N_STEPS': 1024, 'PPO_N_EPOCHS': 11, 'CLIP_RANGE': 0.1873687420594126, 'ENT_COEF': 0.01223705789444759, 'GAMMA': 0.9655797544260817, 'STEP_PENALTY': -0.14741396326366074, 'FAIL_PENALTY': -6.702743410356774, 'GOAL_BONUS': 5.104629857953324, 'SAME_CELL_PENALTY': -1.1444721158209594, 'DISTANCE_REWARD_SCALE': 15.83703155911875, 'DISTANCE_GAMMA': 0.9805693775365445}. Best is trial 7 with value: 275.0.
# ---> Starting Optuna Trial 9 <---
#   --- Hyperparameters for this Trial ---
#   PPO Agent:
#     Learning Rate: 0.000228
#     N_Steps: 1024
#     N_Epochs: 5
#     Clip Range: 0.2615
#     Entropy Coef: 0.006427
#     Gamma (Discount): 0.9961
#   Reward Function:
#     Goal Bonus: 6.9107
#     Fail Penalty: -2.4778
#     Step Penalty: -0.1877
#     Same Cell Penalty: -0.8185
#     Distance Reward Scale: 17.3064
#     Distance Gamma (PBRS): 0.9850
#   ------------------------------------
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>../celloracle_data/optuna_hpo_wandb_logs2/wandb/run-20250909_132741-jrr0stsw</code>
# Syncing run <strong><a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/jrr0stsw' target="_blank">2025-09-09_13-27-41_6.910743436848602_-2.4778486967138513_-0.18774866404702079_17.306432105921402_True</a></strong> to <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt</a>
#  View run at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/jrr0stsw' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/jrr0stsw</a>
# --- Starting Training Run ---
# Configuration: {'ORACLE_PATH': '../celloracle_data/celloracle_object/new_promoter_without_mescs_trimmed_test_own_umap/ready_oracle.pkl', 'MODEL_SAVE_PATH_BASE': '../celloracle_data/optuna_hpo_models2', 'LOG_DIR_BASE': '../celloracle_data/optuna_hpo_logs2', 'WAND_B_LOG_DIR_BASE': '../celloracle_data/optuna_hpo_wandb_logs2', 'HPO_FIXED_MAX_STEPS_PER_EPISODE': 20, 'TRANSITION_MATRIX': '../celloracle_data/transition_matrix/transition_matrix.pkl', 'BATCH_SIZE': 256, 'USE_MASKABLE_PPO': False, 'VERBOSE': 0, 'LOG_INTERVAL': 10, 'RESET_NUM_TIMESTEPS': False, 'DEVICE': 'auto', 'USE_PROGRESS_BAR': False, 'STEP_SAVE_FREQ': 1000000000, 'PPO_N_STEPS': 1024, 'PPO_N_EPOCHS': 5, 'GAMMA': 0.9960990017103981, 'GAE_LAMBDA': 0.95, 'CLIP_RANGE': 0.2615054309182247, 'ENT_COEF': 0.006426865822891632, 'VF_COEF': 0.5, 'MAX_GRAD_NORM': 0.5, 'LEARNING_RATE': 0.00022798162142296694, 'ALLOW_GENE_ACTIVATION': True, 'STANDARD_SD_FACTOR': 1.5, 'USE_LEARNING_RATE_SCHEDULE': False, 'USE_SIMILARITY_REWARD': True, 'ENV_TYPE': 'FAST', 'USE_PREV_KNOCKOUT': True, 'DIVIDER_OF_TOTAL_STEPS_FOR_CURRICULUM_LEARNING': 20, 'TARGET_CELLS_PER_PHASE': 14, 'MAX_STEP_INCREASE_PER_PHASE': 8, 'MAX_STEPS_FIRST_PHASE': 50000, 'PHASE_STEP_INCREASE': 15000, 'MAX_STEPS_PER_EPISODE': 42, 'OPTUNA_REPORT_INTERVAL': 10000, 'GENE_ACTIVITY_THRESHOLD': 0.01, 'TARGET_DISTANCE_THRESHOLD': 0.1, 'DISTANCE_GAMMA': 0.9849749616554677, 'STEP_PENALTY': -0.18774866404702079, 'GOAL_BONUS': 6.910743436848602, 'FAIL_PENALTY': -2.4778486967138513, 'SAME_CELL_PENALTY': -0.818533856070033, 'DISTANCE_REWARD_SCALE': 17.306432105921402, 'PARAMETER_TUNING': True, 'TOTAL_TIMESTEPS_HPO': 300000, 'STUDY_NAME': 'ppo_celloracle_hpo_general20', 'STORAGE_NAME': 'sqlite:///ppo_celloracle_hpo_general20.db', 'PI_ARCH': [512, 256], 'VF_ARCH': [512, 256], 'ACTIVATION_FN': <class 'torch.nn.modules.activation.ReLU'>, 'MODEL_SAVE_PATH': '../celloracle_data/optuna_hpo_models2/trial_9', 'LOG_DIR': '../celloracle_data/optuna_hpo_logs2/trial_9', 'WANDB_RUN_NAME': 't9_lr2.3e-04_ent0.01', 'optuna_trial_obj': <optuna.trial._trial.Trial object at 0x74b38413bd00>, 'TOTAL_TIMESTEPS': 300000}
# Initializing CellOracleCustomEnv with batch_size=256...
# CuPy is available and GPU is accessible.
# loaded
# Raw data min: 0.0, max: 18.71354292543993
# AnnData object with n_obs × n_vars = 30000 × 3000
#     obs: 'bc_idx', 'colnames', 'obs_names', 'celltype', 'celltype_general'
#     var: 'rownames', 'mean', 'std', 'symbol', 'isin_top1000_var_mean_genes', 'isin_TFdict_targets', 'isin_TFdict_regulators', 'isin_actve_regulators'
#     uns: 'celltype_colors', 'neighbors', 'pca', 'umap', 'umap_neighbors_sparse'
#     obsm: 'X_pca', 'X_umap', 'colnames_factor', 'umap_neighbors'
#     varm: 'PCs'
#     layers: 'chic', 'raw_chich_counts', 'raw_count', 'unspliced_spliced', 'normalized_count', 'imputed_count', 'simulation_input'
#     obsp: 'connectivities', 'distances', 'umap_neighbors_sparse'
# Finished calculating activation values for 108 genes.
# get attribute called with name:  render_mode
# get attribute called with indices:  None
# UMAP coordinates normalized with StandardScaler with amx:  0.99999994  and min:  -1.0
# Calculating centroid for celltype: Floor Plate Neural Tube, number of cells: 3024
# Final centroid for celltype Floor Plate Neural Tube: [0.15103018 3.5827925 ], norm: [-0.26755098 -0.36702746]
# Calculating centroid for celltype: Reprogramming PGCs, number of cells: 410
# Final centroid for celltype Reprogramming PGCs: [-0.13800415 10.545729  ], norm: [-0.30736113  0.52565503]
# Calculating centroid for celltype: Caudal Mesoderm, number of cells: 2869
# Final centroid for celltype Caudal Mesoderm: [-0.34028184  8.111842  ], norm: [-0.33522215  0.21362104]
# Calculating centroid for celltype: Naive PGCs, number of cells: 1580
# Final centroid for celltype Naive PGCs: [-0.36913848 12.424707  ], norm: [-0.33919668  0.76654875]
# Calculating centroid for celltype: Epiblast, number of cells: 1999
# Final centroid for celltype Epiblast: [-3.0602849 11.13454  ], norm: [-0.70986354  0.60114324]
# Calculating centroid for celltype: NMPs, number of cells: 1076
# Final centroid for celltype NMPs: [0.3204247 6.6997905], norm: [-0.24421889  0.03258687]
# Calculating centroid for celltype: (pre)Somitic/Wavefront, number of cells: 1143
# Final centroid for celltype (pre)Somitic/Wavefront: [1.4744222 7.961644 ], norm: [-0.08527257  0.19436264]
# Calculating centroid for celltype: Dermomyotome, number of cells: 1208
# Final centroid for celltype Dermomyotome: [3.346641 5.715721], norm: [ 0.17259867 -0.09357524]
# Calculating centroid for celltype: PGCs, number of cells: 1080
# Final centroid for celltype PGCs: [ 0.35939455 12.803531  ], norm: [-0.23885158  0.8151156 ]
# Calculating centroid for celltype: LP/Intermediate Mesoderm, number of cells: 1079
# Final centroid for celltype LP/Intermediate Mesoderm: [4.1093826 6.2413793], norm: [ 0.27765545 -0.0261833 ]
# Calculating centroid for celltype: Pharyngeal Mesoderm, number of cells: 967
# Final centroid for celltype Pharyngeal Mesoderm: [5.4362154 6.075975 ], norm: [ 0.46040708 -0.04738893]
# Calculating centroid for celltype: Caudal Epiblast, number of cells: 2634
# Final centroid for celltype Caudal Epiblast: [-0.7592888  9.8951235], norm: [-0.39293417  0.4422448 ]
# Calculating centroid for celltype: Neural Progenitors, number of cells: 1861
# Final centroid for celltype Neural Progenitors: [-0.19399272  5.780165  ], norm: [-0.3150727  -0.08531348]
# Calculating centroid for celltype: Late Motor Neurons, number of cells: 840
# Final centroid for celltype Late Motor Neurons: [3.319404  0.4959957], norm: [ 0.16884682 -0.7627698 ]
# Calculating centroid for celltype: Cardiac Mesoderm, number of cells: 720
# Final centroid for celltype Cardiac Mesoderm: [5.5995193 8.459149 ], norm: [0.4829008  0.25814468]
# Calculating centroid for celltype: Early Motor Neurons, number of cells: 793
# Final centroid for celltype Early Motor Neurons: [2.182444  2.2965121], norm: [ 0.01224715 -0.5319347 ]
# Calculating centroid for celltype: Roof Plate Neural Tube, number of cells: 1336
# Final centroid for celltype Roof Plate Neural Tube: [-1.1425856  4.133491 ], norm: [-0.44572777 -0.29642552]
# Calculating centroid for celltype: Primitive Streak, number of cells: 183
# Final centroid for celltype Primitive Streak: [ 0.41268933 10.246578  ], norm: [-0.23151112  0.48730245]
# Calculating centroid for celltype: Nascent Mesoderm, number of cells: 730
# Final centroid for celltype Nascent Mesoderm: [3.5888844 9.237035 ], norm: [0.20596404 0.3578744 ]
# Calculating centroid for celltype: Visceral Endoderm, number of cells: 1931
# Final centroid for celltype Visceral Endoderm: [ 4.248622 11.432925], norm: [0.29683396 0.6393976 ]
# Calculating centroid for celltype: Endothelium, number of cells: 436
# Final centroid for celltype Endothelium: [8.347851  6.3133297], norm: [ 0.86144304 -0.01695901]
# Calculating centroid for celltype: ExE Endoderm, number of cells: 582
# Final centroid for celltype ExE Endoderm: [ 5.838832 12.053093], norm: [0.51586205 0.7189068 ]
# Calculating centroid for celltype: Sclerotome, number of cells: 529
# Final centroid for celltype Sclerotome: [4.6159496 6.0439634], norm: [ 0.34742755 -0.05149309]
# Calculating centroid for celltype: (early) Somite, number of cells: 524
# Final centroid for celltype (early) Somite: [4.6244535 7.075751 ], norm: [0.34859833 0.08078694]
# Calculating centroid for celltype: Erythrocytes, number of cells: 68
# Final centroid for celltype Erythrocytes: [7.9770355 7.998386 ], norm: [0.81036866 0.19907323]
# Calculating centroid for celltype: Parietal Endoderm, number of cells: 128
# Final centroid for celltype Parietal Endoderm: [ 3.3503137 13.78757  ], norm: [0.1731044 0.9412746]
# Calculating centroid for celltype: Epidermis Progenitors, number of cells: 144
# Final centroid for celltype Epidermis Progenitors: [-4.64016  10.502207], norm: [-0.9274685   0.52007526]
# Calculating centroid for celltype: Megakaryocytes, number of cells: 53
# Final centroid for celltype Megakaryocytes: [8.893026 8.032934], norm: [0.9365332  0.20350246]
# Calculating centroid for celltype: Cardiomyocytes, number of cells: 53
# Final centroid for celltype Cardiomyocytes: [7.0683675 8.852559 ], norm: [0.68521273 0.30858237]
# Calculating centroid for celltype: Myotome, number of cells: 20
# Final centroid for celltype Myotome: [4.0142164 3.6796944], norm: [ 0.26454744 -0.35460392]
# Number of phases for curriculum learning: 4
# number of targets: 14
# 3 targets for phase 1
# 3 targets for phase 2
# 3 targets for phase 3
# 3 targets for phase 4
# Total curriculum targets computed for phases: 4
# Total curriculum targets for each phase: [3, 3, 3, 3]
# Total number of celltypes in curriculum: [14, 14, 14]
# Number of celltypes:  30  so without pcgs we have  27  targets
# Generating UMAP plot with goal regions (radius: 0.2)...
# Plot saved to: umap_with_goal_regions.png
# Policy architecture: {'net_arch': {'pi': [512, 256], 'vf': [512, 256]}, 'activation_fn': <class 'torch.nn.modules.activation.ReLU'>}
# Agent (PPO) instantiated with architecture: {'pi': [512, 256], 'vf': [512, 256]}
# Starting training for 300000 timesteps...
# Closing environment.
# Total goals achieved in this trial: 312
# Optuna Trial 9 completed. Final Metric (Mean Reward): 312.0000
# Finishing W&B run for trial 9 (Status: completed)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>▄▂▅▃▅▇▅▁▅▄▂▅▇▂▃▅▃▄▄▅▅▅▅▂▄▅█▄▂▅▃▅▂▅▆▅▅▃▅▄</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>█████▁█████████▁█████████▁▁▁████████████</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>▆▅▄▇▇▆█▇█▄▇█▇▆▆█▆▅▇▆▃▁▅▄▄▃▂▂▄▃▂▂▅▄▃▄▄▃▃▂</td></tr><tr><td>episode_overall/success_rate</td><td>██▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▆▆▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>episode_period/ep_len_mean</td><td>▇██▁█▇█▆█▃▇████▇▇█▇▇▆█▇▇██▇█▆█▇█▇▇▇▇▇███</td></tr><tr><td>episode_period/success_rate</td><td>▁▁█▃▆▃▂▁▂▂▁▂▁▁▂▁▂▂▂▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>step_avg/average_distance</td><td>▃▂▁▁▅▇▂▁▆▆▅▇▄▆▂▃▇▆▃▅▂▆▃▄▆▃▂▇▅▄▆▆▆▅▄▂▇▅█▅</td></tr><tr><td>step_avg/average_goal</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁█▁▁█▁▁█▁▁█▁▁</td></tr><tr><td>step_avg/average_penalty</td><td>█████████▁███████████████▄██████████████</td></tr><tr><td>step_avg/average_same_cell</td><td>▅▄▅▄▂▇▅▂▁▃▃▆█▂▇▆█▁▄▃▄▃▅▂█▁▆▆█▇▆▃▄▆█▇▄▂▅▆</td></tr><tr><td>step_avg/percentage_of_activation</td><td>▃▅▇▆▆▇▄▄▅▃▄▂▂▄▅█▃▃▃▄▅▅▆▃▅▅▄▄▄▅▆▃▄▅▅▁▅▅▅▆</td></tr><tr><td>train/approx_kl</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/current_curriculum_phase</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/current_max_episode_steps</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/mean_reward</td><td>▃▆▅▂▇▃▃▄▆▃▅█▃▄▄▇▄▄▅▂▄▇▃▆▅▄▅▄▆▆▁▆▁█▅▅▅▆▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>0.01947</td></tr><tr><td>PPO_update/clip_fraction</td><td>0.11072</td></tr><tr><td>PPO_update/entropy_loss</td><td>-5.35764</td></tr><tr><td>PPO_update/explained_variance</td><td>0.00689</td></tr><tr><td>PPO_update/value_loss</td><td>2.88458</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>17</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>16</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>86</td></tr><tr><td>episode_overall/success_rate</td><td>0.02494</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>12428</td></tr><tr><td>episode_period/ep_len_mean</td><td>41.67442</td></tr><tr><td>episode_period/success_rate</td><td>0.04651</td></tr><tr><td>final_metric_for_optuna</td><td>312</td></tr><tr><td>step_avg/average_distance</td><td>-0.12517</td></tr><tr><td>step_avg/average_goal</td><td>0</td></tr><tr><td>step_avg/avera ...
# ...
#  View project at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt</a>
#  View run at <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/sqkvz8ip' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/sqkvz8ip</a>
# --- Starting Training Run ---
# Configuration: {'ORACLE_PATH': '../celloracle_data/celloracle_object/new_promoter_without_mescs_trimmed_test_own_umap/ready_oracle.pkl', 'MODEL_SAVE_PATH_BASE': '../celloracle_data/optuna_hpo_models2', 'LOG_DIR_BASE': '../celloracle_data/optuna_hpo_logs2', 'WAND_B_LOG_DIR_BASE': '../celloracle_data/optuna_hpo_wandb_logs2', 'HPO_FIXED_MAX_STEPS_PER_EPISODE': 20, 'TRANSITION_MATRIX': '../celloracle_data/transition_matrix/transition_matrix.pkl', 'BATCH_SIZE': 256, 'USE_MASKABLE_PPO': False, 'VERBOSE': 0, 'LOG_INTERVAL': 10, 'RESET_NUM_TIMESTEPS': False, 'DEVICE': 'auto', 'USE_PROGRESS_BAR': False, 'STEP_SAVE_FREQ': 1000000000, 'PPO_N_STEPS': 1024, 'PPO_N_EPOCHS': 11, 'GAMMA': 0.9906785548651297, 'GAE_LAMBDA': 0.95, 'CLIP_RANGE': 0.27638733421513423, 'ENT_COEF': 0.002189724709914371, 'VF_COEF': 0.5, 'MAX_GRAD_NORM': 0.5, 'LEARNING_RATE': 0.00015311765143970443, 'ALLOW_GENE_ACTIVATION': True, 'STANDARD_SD_FACTOR': 1.5, 'USE_LEARNING_RATE_SCHEDULE': False, 'USE_SIMILARITY_REWARD': True, 'ENV_TYPE': 'FAST', 'USE_PREV_KNOCKOUT': True, 'DIVIDER_OF_TOTAL_STEPS_FOR_CURRICULUM_LEARNING': 20, 'TARGET_CELLS_PER_PHASE': 14, 'MAX_STEP_INCREASE_PER_PHASE': 8, 'MAX_STEPS_FIRST_PHASE': 50000, 'PHASE_STEP_INCREASE': 15000, 'MAX_STEPS_PER_EPISODE': 42, 'OPTUNA_REPORT_INTERVAL': 10000, 'GENE_ACTIVITY_THRESHOLD': 0.01, 'TARGET_DISTANCE_THRESHOLD': 0.1, 'DISTANCE_GAMMA': 0.9888904020371371, 'STEP_PENALTY': -0.18169672550430319, 'GOAL_BONUS': 6.656005819840909, 'FAIL_PENALTY': -1.5225708642832116, 'SAME_CELL_PENALTY': -2.041207532658355, 'DISTANCE_REWARD_SCALE': 48.51095192233886, 'PARAMETER_TUNING': True, 'TOTAL_TIMESTEPS_HPO': 300000, 'STUDY_NAME': 'ppo_celloracle_hpo_general20', 'STORAGE_NAME': 'sqlite:///ppo_celloracle_hpo_general20.db', 'PI_ARCH': [512, 256], 'VF_ARCH': [512, 256], 'ACTIVATION_FN': <class 'torch.nn.modules.activation.ReLU'>, 'MODEL_SAVE_PATH': '../celloracle_data/optuna_hpo_models2/trial_10', 'LOG_DIR': '../celloracle_data/optuna_hpo_logs2/trial_10', 'WANDB_RUN_NAME': 't10_lr1.5e-04_ent0.00', 'optuna_trial_obj': <optuna.trial._trial.Trial object at 0x74b25f046530>, 'TOTAL_TIMESTEPS': 300000}
# Initializing CellOracleCustomEnv with batch_size=256...
# CuPy is available and GPU is accessible.
# loaded
# Raw data min: 0.0, max: 18.71354292543993
# AnnData object with n_obs × n_vars = 30000 × 3000
#     obs: 'bc_idx', 'colnames', 'obs_names', 'celltype', 'celltype_general'
#     var: 'rownames', 'mean', 'std', 'symbol', 'isin_top1000_var_mean_genes', 'isin_TFdict_targets', 'isin_TFdict_regulators', 'isin_actve_regulators'
#     uns: 'celltype_colors', 'neighbors', 'pca', 'umap', 'umap_neighbors_sparse'
#     obsm: 'X_pca', 'X_umap', 'colnames_factor', 'umap_neighbors'
#     varm: 'PCs'
#     layers: 'chic', 'raw_chich_counts', 'raw_count', 'unspliced_spliced', 'normalized_count', 'imputed_count', 'simulation_input'
#     obsp: 'connectivities', 'distances', 'umap_neighbors_sparse'
# Finished calculating activation values for 108 genes.
# get attribute called with name:  render_mode
# get attribute called with indices:  None
# UMAP coordinates normalized with StandardScaler with amx:  0.99999994  and min:  -1.0
# Calculating centroid for celltype: Floor Plate Neural Tube, number of cells: 3024
# Final centroid for celltype Floor Plate Neural Tube: [0.15103018 3.5827925 ], norm: [-0.26755098 -0.36702746]
# Calculating centroid for celltype: Reprogramming PGCs, number of cells: 410
# Final centroid for celltype Reprogramming PGCs: [-0.13800415 10.545729  ], norm: [-0.30736113  0.52565503]
# Calculating centroid for celltype: Caudal Mesoderm, number of cells: 2869
# Final centroid for celltype Caudal Mesoderm: [-0.34028184  8.111842  ], norm: [-0.33522215  0.21362104]
# Calculating centroid for celltype: Naive PGCs, number of cells: 1580
# Final centroid for celltype Naive PGCs: [-0.36913848 12.424707  ], norm: [-0.33919668  0.76654875]
# Calculating centroid for celltype: Epiblast, number of cells: 1999
# Final centroid for celltype Epiblast: [-3.0602849 11.13454  ], norm: [-0.70986354  0.60114324]
# Calculating centroid for celltype: NMPs, number of cells: 1076
# Final centroid for celltype NMPs: [0.3204247 6.6997905], norm: [-0.24421889  0.03258687]
# Calculating centroid for celltype: (pre)Somitic/Wavefront, number of cells: 1143
# Final centroid for celltype (pre)Somitic/Wavefront: [1.4744222 7.961644 ], norm: [-0.08527257  0.19436264]
# Calculating centroid for celltype: Dermomyotome, number of cells: 1208
# Final centroid for celltype Dermomyotome: [3.346641 5.715721], norm: [ 0.17259867 -0.09357524]
# Calculating centroid for celltype: PGCs, number of cells: 1080
# Final centroid for celltype PGCs: [ 0.35939455 12.803531  ], norm: [-0.23885158  0.8151156 ]
# Calculating centroid for celltype: LP/Intermediate Mesoderm, number of cells: 1079
# Final centroid for celltype LP/Intermediate Mesoderm: [4.1093826 6.2413793], norm: [ 0.27765545 -0.0261833 ]
# Calculating centroid for celltype: Pharyngeal Mesoderm, number of cells: 967
# Final centroid for celltype Pharyngeal Mesoderm: [5.4362154 6.075975 ], norm: [ 0.46040708 -0.04738893]
# Calculating centroid for celltype: Caudal Epiblast, number of cells: 2634
# Final centroid for celltype Caudal Epiblast: [-0.7592888  9.8951235], norm: [-0.39293417  0.4422448 ]
# Calculating centroid for celltype: Neural Progenitors, number of cells: 1861
# Final centroid for celltype Neural Progenitors: [-0.19399272  5.780165  ], norm: [-0.3150727  -0.08531348]
# Calculating centroid for celltype: Late Motor Neurons, number of cells: 840
# Final centroid for celltype Late Motor Neurons: [3.319404  0.4959957], norm: [ 0.16884682 -0.7627698 ]
# Calculating centroid for celltype: Cardiac Mesoderm, number of cells: 720
# Final centroid for celltype Cardiac Mesoderm: [5.5995193 8.459149 ], norm: [0.4829008  0.25814468]
# Calculating centroid for celltype: Early Motor Neurons, number of cells: 793
# Final centroid for celltype Early Motor Neurons: [2.182444  2.2965121], norm: [ 0.01224715 -0.5319347 ]
# Calculating centroid for celltype: Roof Plate Neural Tube, number of cells: 1336
# Final centroid for celltype Roof Plate Neural Tube: [-1.1425856  4.133491 ], norm: [-0.44572777 -0.29642552]
# Calculating centroid for celltype: Primitive Streak, number of cells: 183
# Final centroid for celltype Primitive Streak: [ 0.41268933 10.246578  ], norm: [-0.23151112  0.48730245]
# Calculating centroid for celltype: Nascent Mesoderm, number of cells: 730
# Final centroid for celltype Nascent Mesoderm: [3.5888844 9.237035 ], norm: [0.20596404 0.3578744 ]
# Calculating centroid for celltype: Visceral Endoderm, number of cells: 1931
# Final centroid for celltype Visceral Endoderm: [ 4.248622 11.432925], norm: [0.29683396 0.6393976 ]
# Calculating centroid for celltype: Endothelium, number of cells: 436
# Final centroid for celltype Endothelium: [8.347851  6.3133297], norm: [ 0.86144304 -0.01695901]
# Calculating centroid for celltype: ExE Endoderm, number of cells: 582
# Final centroid for celltype ExE Endoderm: [ 5.838832 12.053093], norm: [0.51586205 0.7189068 ]
# Calculating centroid for celltype: Sclerotome, number of cells: 529
# Final centroid for celltype Sclerotome: [4.6159496 6.0439634], norm: [ 0.34742755 -0.05149309]
# Calculating centroid for celltype: (early) Somite, number of cells: 524
# Final centroid for celltype (early) Somite: [4.6244535 7.075751 ], norm: [0.34859833 0.08078694]
# Calculating centroid for celltype: Erythrocytes, number of cells: 68
# Final centroid for celltype Erythrocytes: [7.9770355 7.998386 ], norm: [0.81036866 0.19907323]
# Calculating centroid for celltype: Parietal Endoderm, number of cells: 128
# Final centroid for celltype Parietal Endoderm: [ 3.3503137 13.78757  ], norm: [0.1731044 0.9412746]
# Calculating centroid for celltype: Epidermis Progenitors, number of cells: 144
# Final centroid for celltype Epidermis Progenitors: [-4.64016  10.502207], norm: [-0.9274685   0.52007526]
# Calculating centroid for celltype: Megakaryocytes, number of cells: 53
# Final centroid for celltype Megakaryocytes: [8.893026 8.032934], norm: [0.9365332  0.20350246]
# Calculating centroid for celltype: Cardiomyocytes, number of cells: 53
# Final centroid for celltype Cardiomyocytes: [7.0683675 8.852559 ], norm: [0.68521273 0.30858237]
# Calculating centroid for celltype: Myotome, number of cells: 20
# Final centroid for celltype Myotome: [4.0142164 3.6796944], norm: [ 0.26454744 -0.35460392]
# Number of phases for curriculum learning: 4
# number of targets: 14
# 3 targets for phase 1
# 3 targets for phase 2
# 3 targets for phase 3
# 3 targets for phase 4
# Total curriculum targets computed for phases: 4
# Total curriculum targets for each phase: [3, 3, 3, 3]
# Total number of celltypes in curriculum: [14, 14, 14]
# Number of celltypes:  30  so without pcgs we have  27  targets
# Generating UMAP plot with goal regions (radius: 0.2)...
# Plot saved to: umap_with_goal_regions.png
# Policy architecture: {'net_arch': {'pi': [512, 256], 'vf': [512, 256]}, 'activation_fn': <class 'torch.nn.modules.activation.ReLU'>}
# Agent (PPO) instantiated with architecture: {'pi': [512, 256], 'vf': [512, 256]}
# Starting training for 300000 timesteps...
# Closing environment.
# Total goals achieved in this trial: 332
# Optuna Trial 10 completed. Final Metric (Mean Reward): 332.0000
# Finishing W&B run for trial 10 (Status: completed)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_update/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>▃▃▃▃▂▄▅▅▆▁▄▅▃▇▅▂▆▃▇▅▆▅▃█▄▅▂▄▅▄▅▄▅▃▅▄▅▅▃▄</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>███▁███████████▁███▁█████████▁▁█▁███████</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>▅▃▆▄▆▃▆▇▆▇█▅▇▆▆▅▆▇▆▄▄▂▃▃▄▄▅▅▄▃▃▂▃▄▄▅▄▅▅▁</td></tr><tr><td>episode_overall/success_rate</td><td>▅█▆▅▂▃▂▂▂▂▂▃▂▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▅▆▆</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇████</td></tr><tr><td>episode_period/ep_len_mean</td><td>█▆████▄▆█▁▅█▄▆█▇▅▇▅▆▄▇█▇▆▇█▅▇▄▆▆█▇▆█▇▆▆▆</td></tr><tr><td>episode_period/success_rate</td><td>█▅▆▁▂▁▁▂▁▂▁▁▁▂▁▂▁▁▂▂▁▂▁▂▂▂▁▁▂▁▁▁▂▁▁▁▁▁▁▁</td></tr><tr><td>step_avg/average_distance</td><td>▄▄▅▅▄▃▃▄▄▄▁▅▄▅▂▆▃▄▆▅▇▆▄▄▅▃▄▇▇▆▆▆▆▅▆▅▅█▆█</td></tr><tr><td>step_avg/average_goal</td><td>▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁▁▁▁█▁▁█▁▁▁▁▁▁</td></tr><tr><td>step_avg/average_penalty</td><td>███▇▆▇█▇▇▇▆▆▇▇▇▇▅▅▇▇▆▇▇▇▅▄▇▇▅▃▇▅▄▆▆▄▂▄▁▅</td></tr><tr><td>step_avg/average_same_cell</td><td>▂▁▃▇▆█▅▅▅▆▅▅▅▅▃▃▅▄▄▄▆▅▅▂▆▅▅▅▄▅▅█▆▇▅▆▆▅▄▆</td></tr><tr><td>step_avg/percentage_of_activation</td><td>▁▄▅▅▃▄▃▄▃▇▅▃▃▄▃▅▅▇▆▁▅▆▂▃▆█▅▄▄▁▄▅▃▄▆▂▃▃▇▁</td></tr><tr><td>train/approx_kl</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/current_curriculum_phase</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/current_max_episode_steps</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_info/mean_reward</td><td>▂▂▂▃▃▁▂▄▂▅▂▄▁▃▄▄▃▄▁▃▃▃▃▂▄▅▅▄▃▄▃▄▄▃▅▂▄█▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>PPO_update/approx_kl</td><td>0.02336</td></tr><tr><td>PPO_update/clip_fraction</td><td>0.15583</td></tr><tr><td>PPO_update/entropy_loss</td><td>-5.35362</td></tr><tr><td>PPO_update/explained_variance</td><td>5e-05</td></tr><tr><td>PPO_update/value_loss</td><td>11.92208</td></tr><tr><td>batch_diversity/num_unique_current_types</td><td>16</td></tr><tr><td>batch_diversity/num_unique_target_types</td><td>16</td></tr><tr><td>diagnostics/same_cell_event_count_period</td><td>110</td></tr><tr><td>episode_overall/success_rate</td><td>0.02652</td></tr><tr><td>episode_overall/total_episodes_collected</td><td>12445</td></tr><tr><td>episode_period/ep_len_mean</td><td>40.73585</td></tr><tr><td>episode_period/success_rate</td><td>0.0566</td></tr><tr><td>final_metric_for_optuna</td><td>332</td></tr><tr><td>step_avg/average_distance</td><td>-0.29034</td></tr><tr><td>step_avg/average_goal</td><td>0</td></tr><tr><td>step_avg/averag ...
#  View run <strong style="color:#cdcd00">2025-09-09_13-29-54_6.656005819840909_-1.5225708642832116_-0.18169672550430319_48.51095192233886_True</strong> at: <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/sqkvz8ip' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt/runs/sqkvz8ip</a><br> View project at: <a href='https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt' target="_blank">https://wandb.ai/caspar-christiaan-utrecht-university/celloracle%20optuna%20opt</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../celloracle_data/optuna_hpo_wandb_logs2/wandb/run-20250909_132954-sqkvz8ip/logs</code>
# [I 2025-09-09 13:33:36,221] Trial 10 finished with value: 332.0 and parameters: {'LEARNING_RATE': 0.00015311765143970443, 'PPO_N_STEPS': 1024, 'PPO_N_EPOCHS': 11, 'CLIP_RANGE': 0.27638733421513423, 'ENT_COEF': 0.002189724709914371, 'GAMMA': 0.9906785548651297, 'STEP_PENALTY': -0.18169672550430319, 'FAIL_PENALTY': -1.5225708642832116, 'GOAL_BONUS': 6.656005819840909, 'SAME_CELL_PENALTY': -2.041207532658355, 'DISTANCE_REWARD_SCALE': 48.51095192233886, 'DISTANCE_GAMMA': 0.9888904020371371}. Best is trial 10 with value: 332.0.
# --- Optuna Study Finished ---
# Study dashboard command: optuna-dashboard sqlite:///ppo_celloracle_hpo_general20.db
# Number of finished trials in study: 11
#   Trials: Completed=10, Pruned=0, Failed=1
#
# Best trial:
#   Value (Maximized Metric): 332.0000
#   Params:
#     LEARNING_RATE: 0.00015311765143970443
#     PPO_N_STEPS: 1024
#     PPO_N_EPOCHS: 11
#     CLIP_RANGE: 0.27638733421513423
#     ENT_COEF: 0.002189724709914371
#     GAMMA: 0.9906785548651297
#     STEP_PENALTY: -0.18169672550430319
#     FAIL_PENALTY: -1.5225708642832116
#     GOAL_BONUS: 6.656005819840909
#     SAME_CELL_PENALTY: -2.041207532658355
#     DISTANCE_REWARD_SCALE: 48.51095192233886
#     DISTANCE_GAMMA: 0.9888904020371371
# Best parameters saved to ../celloracle_data/optuna_hpo_models2/ppo_celloracle_hpo_general20_best_params.txt

# %%
#lts see if gpus work

import os
import torch.nn as nn
import AI as ai_module # Import the refactored script
import ParameterTuning as tuning_module # Import the refactored script
import multiprocessing
import time
    
def worker_process(gpu_id, base_config):
    os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)
    print(f"Worker {gpu_id} started, using GPU {gpu_id}")
    tuning_module.run_optuna_hpo(base_config,gpu_id=gpu_id)
    
def start():
    multiprocessing.set_start_method('spawn', force=True)
    data_path_new_data = os.path.join('../celloracle_data', "celloracle_object/new_promoter_without_mescs_trimmed_test_own_umap")
    base_config = {
        # Paths
        "ORACLE_PATH": os.path.join(data_path_new_data, "ready_oracle.pkl"),
        "MODEL_SAVE_PATH_BASE": os.path.join("../celloracle_data", "optuna_hpo_models2"), # Base for HPO trial models
        "LOG_DIR_BASE": os.path.join('../celloracle_data', "optuna_hpo_logs2"),         # Base for HPO trial logs
        "WAND_B_LOG_DIR_BASE": os.path.join('../celloracle_data', "optuna_hpo_wandb_logs2"), # Base for HPO trial wandb logs
        "HPO_FIXED_MAX_STEPS_PER_EPISODE": 20, 
        "TRANSITION_MATRIX": os.path.join("../celloracle_data/transition_matrix", "transition_matrix.pkl"), # Path to transition matrix
    
    
        "BATCH_SIZE": 256,
        "USE_MASKABLE_PPO": False, 
        "VERBOSE": 0,              
        "LOG_INTERVAL": 10,
        "RESET_NUM_TIMESTEPS": False,
        "DEVICE": "auto",
        "USE_PROGRESS_BAR": False,  
        "STEP_SAVE_FREQ": 1000000000, 
        "PPO_N_STEPS": 512,
        "PPO_N_EPOCHS": 10,
        "GAMMA": 0.99,
        "GAE_LAMBDA": 0.95,
        "CLIP_RANGE": 0.2,
        "ENT_COEF": 0.01,       
        "VF_COEF": 0.5,
        "MAX_GRAD_NORM": 0.5,
        "LEARNING_RATE": 3e-4,  
    
        # Environment Specific 
        "ALLOW_GENE_ACTIVATION": True,
        "STANDARD_SD_FACTOR": 1.5,
        "USE_LEARNING_RATE_SCHEDULE": False, 
        "USE_SIMILARITY_REWARD": True,
        "ENV_TYPE": "FAST",  #options: FIRST,NEW_INPUT, GENERAL,FAST
        "USE_PREV_KNOCKOUT": False, 
    
        # ENV HYPERPARAMETERS (Some will be tuned by Optuna)
        "DIVIDER_OF_TOTAL_STEPS_FOR_CURRICULUM_LEARNING": 20,
        "TARGET_CELLS_PER_PHASE": 14,
        "MAX_STEP_INCREASE_PER_PHASE": 8,
        "MAX_STEPS_FIRST_PHASE": 50000, 
        "PHASE_STEP_INCREASE": 15000,
        "MAX_STEPS_PER_EPISODE": 42,
        "OPTUNA_REPORT_INTERVAL": 10000,
    
        # Other ENV params
        "GENE_ACTIVITY_THRESHOLD": 0.01,
        "TARGET_DISTANCE_THRESHOLD": 0.1,
        "DISTANCE_GAMMA": 0.99,           
        "STEP_PENALTY": -0.05,
        "GOAL_BONUS": 10,
        "FAIL_PENALTY": -3,
        "SAME_CELL_PENALTY": -0.5,
        "DISTANCE_REWARD_SCALE": 5,
        "PARAMETER_TUNING":True,
        "TOTAL_TIMESTEPS_HPO": 4000000,
        "STUDY_NAME": "ppo_celloracle_hpo_general10",
        "STORAGE_NAME": "sqlite:///ppo_celloracle_hpo_general10.db",
    
        # NN Architecture (Fixed for this example, but can be tuned)
        "PI_ARCH": [512,256],
        "VF_ARCH": [512,256],
        "ACTIVATION_FN": nn.ReLU, # Make sure nn is imported if you use this directly
        
    }
    
    if base_config["USE_SIMILARITY_REWARD"]:
        base_config["DISTANCE_REWARD_SCALE"] = 50
    else:
        base_config["DISTANCE_REWARD_SCALE"] = 5

        
    num_gpus = 2
    processes = []
    for gpu_id in range(num_gpus):
        print("test")
        p = multiprocessing.Process(target=worker_process, args=(gpu_id, base_config))
        processes.append(p)
        p.start()
        time.sleep(5)  # Stagger the start time slightly
        
    for p in processes:
        p.join()
        
if __name__ == '__main__':
    start()
# Out:
# test
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/caspar/miniconda3/envs/gpu_cell_oracle/lib/python3.10/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/caspar/miniconda3/envs/gpu_cell_oracle/lib/python3.10/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'worker_process' on <module '__main__' (built-in)>
# test
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/caspar/miniconda3/envs/gpu_cell_oracle/lib/python3.10/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/caspar/miniconda3/envs/gpu_cell_oracle/lib/python3.10/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'worker_process' on <module '__main__' (built-in)>
